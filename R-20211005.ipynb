# %% [markdown]
# <a href="https://colab.research.google.com/github/ivangelion68/r/blob/main/R-20211005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system('sudo apt-get install -y librsvg2-dev', intern=TRUE)
# Out:
#  [1] "Reading package lists..."
#  [2] "Building dependency tree..."
#  [3] "Reading state information..."
#  [4] "The following additional packages will be installed:"
#  [5] "  gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0"
#  [6] "  libcairo-script-interpreter2 libcairo2-dev libgdk-pixbuf2.0-dev"
#  [7] "  libpixman-1-dev libxcb-shm0-dev"
#  [8] "Suggested packages:"
#  [9] "  libcairo2-doc librsvg2-doc"
# [10] "The following NEW packages will be installed:"
# [11] "  gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-rsvg-2.0"
# [12] "  libcairo-script-interpreter2 libcairo2-dev libgdk-pixbuf2.0-dev"
# [13] "  libpixman-1-dev librsvg2-dev libxcb-shm0-dev"
# [14] "0 upgraded, 9 newly installed, 0 to remove and 37 not upgraded."
# [15] "Need to get 1,009 kB of archives."
# [16] "After this operation, 4,571 kB of additional disk space will be used."
# [17] "Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]"
# [18] "Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]"
# [19] "Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-rsvg-2.0 amd64 2.40.20-2ubuntu0.2 [3,764 B]"
# [20] "Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]"
# [21] "Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]"
# [22] "Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]"
# [23] "Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]"
# [24] "Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]"
# [25] "Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 librsvg2-dev amd64 2.40.20-2ubuntu0.2 [10.7 kB]"
# [26] "Fetched 1,009 kB in 1s (1,494 kB/s)"
# [27] "Selecting previously unselected package gir1.2-freedesktop:amd64.\r"
# [28] "(Reading database ... \r(Reading database ... 5%\r(Reading database ... 10%\r(Reading database ... 15%\r(Reading database ... 20%\r(Reading database ... 25%\r(Reading database ... 30%\r(Reading database ... 35%\r(Reading database ... 40%\r(Reading database ... 45%\r(Reading database ... 50%\r(Reading database ... 55%\r(Reading database ... 60%\r(Reading database ... 65%\r(Reading database ... 70%\r(Reading database ... 75%\r(Reading database ... 80%\r(Reading database ... 85%\r(Reading database ... 90%\r(Reading database ... 95%\r(Reading database ... 100%\r(Reading database ... 155047 files and directories currently installed.)\r"
# [29] "Preparing to unpack .../0-gir1.2-freedesktop_1.56.1-1_amd64.deb ...\r"
# [30] "Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...\r"
# [31] "Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.\r"
# [32] "Preparing to unpack .../1-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...\r"
# [33] "Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...\r"
# [34] "Selecting previously unselected package gir1.2-rsvg-2.0:amd64.\r"
# [35] "Preparing to unpack .../2-gir1.2-rsvg-2.0_2.40.20-2ubuntu0.2_amd64.deb ...\r"
# [36] "Unpacking gir1.2-rsvg-2.0:amd64 (2.40.20-2ubuntu0.2) ...\r"
# [37] "Selecting previously unselected package libcairo-script-interpreter2:amd64.\r"
# [38] "Preparing to unpack .../3-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...\r"
# [39] "Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [40] "Selecting previously unselected package libpixman-1-dev:amd64.\r"
# [41] "Preparing to unpack .../4-libpixman-1-dev_0.34.0-2_amd64.deb ...\r"
# [42] "Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...\r"
# [43] "Selecting previously unselected package libxcb-shm0-dev:amd64.\r"
# [44] "Preparing to unpack .../5-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...\r"
# [45] "Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...\r"
# [46] "Selecting previously unselected package libcairo2-dev:amd64.\r"
# [47] "Preparing to unpack .../6-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...\r"
# [48] "Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [49] "Selecting previously unselected package libgdk-pixbuf2.0-dev.\r"
# [50] "Preparing to unpack .../7-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...\r"
# [51] "Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...\r"
# [52] "Selecting previously unselected package librsvg2-dev:amd64.\r"
# [53] "Preparing to unpack .../8-librsvg2-dev_2.40.20-2ubuntu0.2_amd64.deb ...\r"
# [54] "Unpacking librsvg2-dev:amd64 (2.40.20-2ubuntu0.2) ...\r"
# [55] "Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [56] "Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...\r"
# [57] "Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...\r"
# [58] "Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...\r"
# [59] "Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...\r"
# [60] "Setting up libpixman-1-dev:amd64 (0.34.0-2) ...\r"
# [61] "Setting up gir1.2-rsvg-2.0:amd64 (2.40.20-2ubuntu0.2) ...\r"
# [62] "Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...\r"
# [63] "Setting up librsvg2-dev:amd64 (2.40.20-2ubuntu0.2) ...\r"
# [64] "Processing triggers for man-db (2.8.3-2ubuntu0.1) ...\r"
# [65] "Processing triggers for libc-bin (2.27-3ubuntu1.3) ...\r"
# [66] "/sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link\r"
# [67] "\r"

# %%
system('ls $R_HOME')

# %%
cat(system('env'))
# Out:
# 0

# %%
str(allPackage <- installed.packages())
allPackage [, c(1,3:5)]
# Out:
#  chr [1:157, 1:16] "IRdisplay" "IRkernel" "pbdZMQ" "repr" "askpass" ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:157] "IRdisplay" "IRkernel" "pbdZMQ" "repr" ...
#   ..$ : chr [1:16] "Package" "LibPath" "Version" "Priority" ...
#             Package     Version Priority
# IRdisplay   IRdisplay   1.0     NA
# IRkernel    IRkernel    1.2     NA
# pbdZMQ      pbdZMQ      0.3-5   NA
# repr        repr        1.1.3   NA
# askpass     askpass     1.1     NA
# assertthat  assertthat  0.2.1   NA
# backports   backports   1.2.1   NA
# base64enc   base64enc   0.1-3   NA
# bit         bit         4.0.4   NA
# bit64       bit64       4.0.5   NA
# blob        blob        1.2.2   NA
# brew        brew        1.0-6   NA
# brio        brio        1.1.2   NA
# broom       broom       0.7.9   NA
# cachem      cachem      1.0.6   NA
# callr       callr       3.7.0   NA
# cellranger  cellranger  1.1.0   NA
# cli         cli         3.0.1   NA
# clipr       clipr       0.7.1   NA
# colorspace  colorspace  2.0-2   NA
# commonmark  commonmark  1.7     NA
# cpp11       cpp11       0.3.1   NA
# crayon      crayon      1.4.1   NA
# credentials credentials 1.3.1   NA
# curl        curl        4.3.2   NA
# data.table  data.table  1.14.0  NA
# DBI         DBI         1.1.1   NA
# dbplyr      dbplyr      2.1.1   NA
# desc        desc        1.3.0   NA
# devtools    devtools    2.4.2   NA
# ⋮           ⋮           ⋮       ⋮
# zip         zip         2.2.0   NA
# base        base        4.1.1   base
# boot        boot        1.3-28  recommended
# class       class       7.3-19  recommended
# cluster     cluster     2.1.2   recommended
# codetools   codetools   0.2-18  recommended
# compiler    compiler    4.1.1   base
# datasets    datasets    4.1.1   base
# foreign     foreign     0.8-81  recommended
# graphics    graphics    4.1.1   base
# grDevices   grDevices   4.1.1   base
# grid        grid        4.1.1   base
# KernSmooth  KernSmooth  2.23-20 recommended
# lattice     lattice     0.20-45 recommended
# MASS        MASS        7.3-54  recommended
# Matrix      Matrix      1.3-4   recommended
# methods     methods     4.1.1   base
# mgcv        mgcv        1.8-37  recommended
# nlme        nlme        3.1-152 recommended
# nnet        nnet        7.3-16  recommended
# parallel    parallel    4.1.1   base
# rpart       rpart       4.1-15  recommended
# spatial     spatial     7.3-14  recommended
# splines     splines     4.1.1   base
# stats       stats       4.1.1   base
# stats4      stats4      4.1.1   base
# survival    survival    3.2-13  recommended
# tcltk       tcltk       4.1.1   base
# tools       tools       4.1.1   base
# utils       utils       4.1.1   base
#             Depends
# IRdisplay   R (>= 3.0.1)
# IRkernel    R (>= 3.2.0)
# pbdZMQ      R (>= 3.5.0)
# repr        R (>= 3.0.1)
# askpass     NA
# assertthat  NA
# backports   R (>= 3.0.0)
# base64enc   R (>= 2.9.0)
# bit         R (>= 2.9.2)
# bit64       R (>= 3.0.1), bit (>= 4.0.0), utils, methods, stats
# blob        NA
# brew        NA
# brio        NA
# broom       R (>= 3.1)
# cachem      NA
# callr       NA
# cellranger  R (>= 3.0.0)
# cli         R (>= 2.10)
# clipr       NA
# colorspace  R (>= 3.0.0), methods
# commonmark  NA
# cpp11       NA
# crayon      NA
# credentials NA
# curl        R (>= 3.0.0)
# data.table  R (>= 3.1.0)
# DBI         methods, R (>= 3.0.0)
# dbplyr      R (>= 3.1)
# desc        R (>= 3.1.0)
# devtools    R (>= 3.0.2), usethis (>= 2.0.1)
# ⋮           ⋮
# zip         NA
# base        NA
# boot        R (>= 3.0.0), graphics, stats
# class       R (>= 3.0.0), stats, utils
# cluster     R (>= 3.4.0)
# codetools   R (>= 2.1)
# compiler    NA
# datasets    NA
# foreign     R (>= 4.0.0)
# graphics    NA
# grDevices   NA
# grid        NA
# KernSmooth  R (>= 2.5.0), stats
# lattice     R (>= 3.0.0)
# MASS        R (>= 3.3.0), grDevices, graphics, stats, utils
# Matrix      R (>= 3.5.0)
# methods     NA
# mgcv        R (>= 3.6.0), nlme (>= 3.1-64)
# nlme        R (>= 3.4.0)
# nnet        R (>= 3.0.0), stats, utils
# parallel    NA
# rpart       R (>= 2.15.0), graphics, stats, grDevices
# spatial     R (>= 3.0.0), graphics, stats, utils
# splines     NA
# stats       NA
# stats4      NA
# survival    R (>= 3.5.0)
# tcltk       NA
# tools       NA
# utils       NA

# %%
install.packages("tidyverse",repos="https://cran.r-project.org/", dependencies = TRUE, configure.args = c("--with-proj-lib=$R_HOME/lib"))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘lazyeval’, ‘rex’, ‘covr’, ‘feather’

# %%
install.packages("dlookr",repos="https://cran.r-project.org/", dependencies = TRUE, configure.args = c("--with-proj-lib=$R_HOME/lib"))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘xts’, ‘TTR’, ‘AsioHeaders’, ‘sass’, ‘proxy’, ‘quadprog’, ‘quantmod’, ‘extrafontdb’, ‘Rttf2pt1’, ‘gdtools’, ‘webshot’, ‘bookdown’, ‘later’, ‘servr’, ‘httpuv’, ‘websocket’, ‘libcoin’, ‘mvtnorm’, ‘Formula’, ‘inum’, ‘htmlwidgets’, ‘reactR’, ‘xtable’, ‘fontawesome’, ‘sourcetools’, ‘promises’, ‘bslib’, ‘e1071’, ‘fracdiff’, ‘lmtest’, ‘timeDate’, ‘tseries’, ‘urca’, ‘zoo’, ‘RcppArmadillo’, ‘plogr’, ‘extrafont’, ‘gridExtra’, ‘hrbrthemes’, ‘kableExtra’, ‘mice’, ‘pagedown’, ‘partykit’, ‘reactable’, ‘shiny’, ‘classInt’, ‘forecast’, ‘ISLR’, ‘nycflights13’, ‘randomForest’, ‘prettydoc’, ‘RSQLite’

# %%
devtools::install_github("choonghyunryu/dlookr")

# %%
install.packages("funModeling")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘bitops’, ‘png’, ‘jpeg’, ‘checkmate’, ‘gtools’, ‘caTools’, ‘latticeExtra’, ‘htmlTable’, ‘viridis’, ‘gplots’, ‘plyr’, ‘Hmisc’, ‘ROCR’, ‘pander’, ‘reshape2’, ‘moments’, ‘entropy’

# %%
install.packages("rmarkdown")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("qcc")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(qcc)
# Out:
# Package 'qcc' version 2.7
#
# Type 'citation("qcc")' for citing this R package in publications.

# %%
freq.caus <- c(6, 22, 13, 2, 5)

# %%
names(freq.caus) <- c("fluct.pot", "contr.inest", "error.oper", "herramgast", "otra")

# %%
pareto.chart(freq.caus, ylab = "Frecuencia",col=rainbow(length(freq.caus)))
# Out:
#
# Pareto chart analysis for freq.caus
#                Frequency  Cum.Freq. Percentage Cum.Percent.
#   contr.inest  22.000000  22.000000  45.833333    45.833333
#   error.oper   13.000000  35.000000  27.083333    72.916667
#   fluct.pot     6.000000  41.000000  12.500000    85.416667
#   otra          5.000000  46.000000  10.416667    95.833333
#   herramgast    2.000000  48.000000   4.166667   100.000000
# plot without title
